# %% [markdown]
# # Operadores de Asignacion (Repaso)

# %%
a = 0
a = a + 5

# %%
a = 2
b = 8

a = b // a
print(a)
# Out:
# 4

# %% [markdown]
# # Estructura de datos

# %% [markdown]
# ## Listas

# %%
datos = []
a = 18

datos = [1, 'A', True, 'Rick', a]
print(datos)
# Out:
# [1, 'A', True, 'Rick', 18]

# %%
# indices
datos[0]
# Out:
# 1

# %%
datos[1]
# Out:
# 'A'

# %%
datos[-1]
# Out:
# 18

# %%
# append
datos.append('sakila')
datos
# Out:
# [1, 'A', True, 'Rick', 18, 'sakila']

# %% [markdown]
# ## Tuplas

# %%
t_direccion = (1, 2, 'a', True)
print(t_direccion[3])
# Out:
# True

# %%
print(t_direccion[-1])
# Out:
# True

# %% [markdown]
# ## Diccionarios

# %%
persona = {}
print(type(persona))
# Out:
# <class 'dict'>

# %%
persona = {'nombre':'Danilo',
            'Edad': 23,
            'Estado_civil':'Soltera'
           }
persona
# Out:
# {'nombre': 'Danilo', 'Edad': 23, 'Estado_civil': 'Soltera'}

# %%
persona['nombre']
# Out:
# 'Danilo'

# %%
persona['Estado_civil']
# Out:
# 'Soltera'

# %%
# modificar elemento del diccionario
persona['Estado_civil'] = 'Soltero'
persona['Estado_civil']
# Out:
# 'Soltero'

# %% [markdown]
# ## Set

# %%
datos_clientes = {1, 2, 3, 1, 2}
datos_clientes
# Out:
# {1, 2, 3}

# %%
pago_clientes = {1, 2}
pago_clientes
# Out:
# {1, 2}

# %%
datos_clientes & pago_clientes
# Out:
# {1, 2}
