# %% [markdown]
# ## Variables

# %%
# imprimir una cadena
print('Alo')
# Out:
# Alo

# %% [markdown]
# Regla de oro: los nombres de las variables deben ser descriptivos

# %%
'''
peso_estudiante = 5
estatura_promedio_estudiante =
avg_estat_estud =
'''

# %% [markdown]
# ## Tipos de datos

# %%
nombre_profe = 'Jeff'
edad_profe = 22
peso_profe = 77.5

# %%
print(type(nombre_profe))
print(type(edad_profe))
print(type(peso_profe))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## Operadores matematicos

# %%
2 / 2
# Out:
# 1.0

# %%
2 * 2
# Out:
# 4

# %%
4 // 2 # division entera
# Out:
# 2

# %%
7 % 3
# Out:
# 1

# %% [markdown]
# ## Input

# %%
input('Como te llamas?')
# Out:
# 'Saul'

# %%
nombre_cliente = input('Como te llamas?')
print(nombre_cliente)
# Out:
# Dani

# %%
edad_cliente = int(input('Que edad tienes?'))
print(edad_cliente)
# Out:
# 32

# %%
print(f'Hola , me llamo {nombre_cliente} y tengo {edad_cliente} años')
# Out:
# Hola , me llamo Dani y tengo 32 años

# %%
print('Hola', nombre_cliente, 'Tienes', edad_cliente, 'años')
# Out:
# Hola Dani Tienes 32 años
