# %%
lista_paises = [
    'Argentina',
    'Bolivia',
    'Ucrania',
    'Espana',
    'Lituania',
    'Colombia'
            
]

print(lista_paises)
# Out:
# ['Argentina', 'Bolivia', 'Ucrania', 'Espana', 'Lituania', 'Colombia']

# %%
lista_paises[-1]
# Out:
# 'Colombia'

# %%
lista_paises.append('Nigeria')
lista_paises
# Out:
# ['Argentina',
#  'Bolivia',
#  'Ucrania',
#  'Espana',
#  'Lituania',
#  'Colombia',
#  'Nigeria']

# %%
lista_paises.reverse()
lista_paises
# Out:
# ['Nigeria',
#  'Colombia',
#  'Lituania',
#  'Espana',
#  'Ucrania',
#  'Bolivia',
#  'Argentina']

# %%
# diccionarios
paises_capitales = {
    'Colombia':'Bogota',
    'Peru':'Lima',
    'Mexico':'Ciudad de Mexico',
    'Bolivia':'La Paz'
}

paises_capitales
# Out:
# {'Colombia': 'Bogota',
#  'Peru': 'Lima',
#  'Mexico': 'Ciudad de Mexico',
#  'Bolivia': 'La Paz'}

# %%
paises_capitales.update({'Venezuela':'Caracas'})
paises_capitales
# Out:
# {'Colombia': 'Bogota',
#  'Peru': 'Lima',
#  'Mexico': 'Ciudad de Mexico',
#  'Bolivia': 'La Paz',
#  'Venezuela': 'Caracas'}

# %%
# tuplas
pass_serv_sql = ('127.0.0.10')
pass_serv_sql
# Out:
# '127.0.0.10'

# %%
# set
estudiantes = {1016, 1235, 2135, 13541}
estudiantes
# Out:
# {1016, 1235, 2135, 13541}
